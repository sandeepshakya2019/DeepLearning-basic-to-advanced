# %% [markdown]
# ## Basics of Python

# %%
name="Sandeep"
# Out:
# Basics of Python

# %%
str1 = "San"
str2 = "San"

print(str1 == str2)
print(str1 is str2)
# Out:
# True
# True

# %%
arr1 = [10,20,30]
arr2 = [10,20,30]

print(arr1 == arr2)
print(arr1 is arr2)
# Out:
# True
# False

# %%
arr1 = 10
arr2 = 10

print(arr1 == arr2)
print(arr1 is arr2)
# Out:
# True
# True

# %%
arr1 = True
arr2 = True

print(arr1 == arr2)
print(arr1 is arr2)
# Out:
# True
# True
